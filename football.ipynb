# %%
import pandas as pd
data_frame = pd.read_csv('data.csv')
data_frame.shape
# Out:
# (18207, 89)

# %%
# Describe features
data_frame.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
# Histograms
data_frame.values
# Out:
# array([[0, 158023, 'L. Messi', ..., 14.0, 8.0, '€226.5M'],
#        [1, 20801, 'Cristiano Ronaldo', ..., 14.0, 11.0, '€127.1M'],
#        [2, 190871, 'Neymar Jr', ..., 15.0, 11.0, '€228.1M'],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 6.0, 13.0, '€165K'],
#        [18205, 246268, 'D. Walker-Rice', ..., 8.0, 9.0, '€143K'],
#        [18206, 246269, 'G. Nugent', ..., 12.0, 9.0, '€165K']],
#       dtype=object)

# %%
data_frame.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data_frame["Age"].hist()
# Out:
# <AxesSubplot:>

# %%
data_frame["Age"].head()
# Out:
# 0    31
# 1    33
# 2    26
# 3    27
# 4    27
# Name: Age, dtype: int64

# %%
data_frame[data_frame["Nationality"]=="Argentina"].head()
# Out:
#     Unnamed: 0      ID        Name  Age  \
# 0            0  158023    L. Messi   31
# 15          15  211110   P. Dybala   24
# 23          23  153079   S. Agüero   30
# 38          38  167664  G. Higuaín   30
# 43          43  201399   M. Icardi   25
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 23  https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38  https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# 43  https://cdn.sofifa.org/players/4/19/201399.png   Argentina
#
#                                    Flag  Overall  Potential             Club  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94     FC Barcelona
# 15  https://cdn.sofifa.org/flags/52.png       89         94         Juventus
# 23  https://cdn.sofifa.org/flags/52.png       89         89  Manchester City
# ...

# %%
data_frame.sort_values("Age", ascending=False).head()
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 4741         4741  140029       O. Pérez   45
# 18183       18183   53748  K. Pilkington   44
# 17726       17726   51963      T. Warner   44
# 10545       10545  140183    S. Narazaki   42
# 7225         7225  142998       C. Muñoz   41
#
#                                                 Photo        Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png             Mexico
# 18183   https://cdn.sofifa.org/players/4/19/53748.png            England
# 17726   https://cdn.sofifa.org/players/4/19/51963.png  Trinidad & Tobago
# 10545  https://cdn.sofifa.org/players/4/19/140183.png              Japan
# 7225   https://cdn.sofifa.org/players/4/19/142998.png          Argentina
#
#                                        Flag  Overall  Potential  \
# 4741    https://cdn.sofifa.org/flags/83.png       71         71
# 18183   https://cdn.sofifa.org/flags/14.png       48         48
# ...

# %%
# Unique values
data_frame["Nationality"].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
club_group = data_frame.groupby("Club")
club_group.mean()
# Out:
#                          Unnamed: 0             ID        Age    Overall  \
# Club
#  SSV Jahn Regensburg    9405.310345  219059.413793  25.655172  65.586207
# 1. FC Heidenheim 1846   9278.428571  219734.142857  24.000000  65.750000
# 1. FC Kaiserslautern   11495.692308  220848.230769  23.846154  63.384615
# 1. FC Köln              5241.035714  208388.714286  24.321429  70.785714
# 1. FC Magdeburg         9514.115385  226487.961538  24.692308  65.615385
# ...                             ...            ...        ...        ...
# Zagłębie Sosnowiec     13864.840000  219129.880000  26.240000  60.760000
# Çaykur Rizespor         8332.900000  211290.833333  25.433333  66.900000
# Örebro SK              13289.296296  224120.185185  24.037037  60.481481
# Östersunds FK          11247.681818  222617.409091  23.863636  63.545455
# Śląsk Wrocław          12043.160000  216246.800000  25.960000  62.200000
#
#                        Potential      Special  International Reputation  \
# Club
# ...

# %%
# Selecting row
data_frame.iloc[0, :] # iloc gets rows (or columns) at particular positions in the index (so it only takes integers)
# Out:
# Unnamed: 0                                                     0
# ID                                                        158023
# Name                                                    L. Messi
# Age                                                           31
# Photo             https://cdn.sofifa.org/players/4/19/158023.png
#                                        ...
# GKHandling                                                  11.0
# GKKicking                                                   15.0
# GKPositioning                                               14.0
# GKReflexes                                                   8.0
# Release Clause                                           €226.5M
# Name: 0, Length: 89, dtype: object

# %%
# Selecting specific value
data_frame.iloc[0, 1]
# Out:
# 158023

# %%
# Selecting by index
data_frame.loc[0] # loc gets rows (or columns) with particular labels from the index
# Out:
# Unnamed: 0                                                     0
# ID                                                        158023
# Name                                                    L. Messi
# Age                                                           31
# Photo             https://cdn.sofifa.org/players/4/19/158023.png
#                                        ...
# GKHandling                                                  11.0
# GKKicking                                                   15.0
# GKPositioning                                               14.0
# GKReflexes                                                   8.0
# Release Clause                                           €226.5M
# Name: 0, Length: 89, dtype: object

# %%
# Rows with at least one NaN <not a number> value
data_frame[pd.isnull(data_frame).any(axis=1)].head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])

def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

wage = df1['Wage'].replace('[\€,]', '', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\€,]', '', regex=True).apply(value_to_float)

df1['Wage'] = wage
df1['Value'] = value

df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#                Name      Wage        Value   difference
# 2         Neymar Jr  290000.0  118500000.0  118210000.0
# 0          L. Messi  565000.0  110500000.0  109935000.0
# 4      K. De Bruyne  355000.0  102000000.0  101645000.0
# 5         E. Hazard  340000.0   93000000.0   92660000.0
# 15        P. Dybala  205000.0   89000000.0   88795000.0
# ...             ...       ...          ...          ...
# 17752   S. Phillips    1000.0          0.0      -1000.0
# 12192  H. Sulaimani    3000.0          0.0      -3000.0
# 3550    S. Nakamura    4000.0          0.0      -4000.0
# 4228       B. Nivet    5000.0          0.0      -5000.0
# 864          Hilton   18000.0          0.0     -18000.0
#
# [18207 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")]
)

p = figure(title="Football 2019", x_axis_label='Wage', y_axis_label='Value', plot_width=700, plot_height=700, tools=[TOOLTIPS])
p.circle('Wage', 'Value', size=10, source=df1)
show(p)
